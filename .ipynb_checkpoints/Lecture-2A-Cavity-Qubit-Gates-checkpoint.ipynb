# %% [markdown]
# # QuTiP lecture: simulation of a two-qubit gate using a resonator as coupler
#
# Author: J.R. Johansson, robert@riken.jp
#
# http://dml.riken.jp/~rob/
#
# Latest version of this ipython notebook lecture are available at: http://github.com/jrjohansson/qutip-lectures

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from qutip import *

# %% [markdown]
# ## Parameters

# %%
N = 10

wc = 5.0 * 2 * pi
w1 = 3.0 * 2 * pi
w2 = 2.0 * 2 * pi

g1 = 0.01 * 2 * pi
g2 = 0.0125 * 2 * pi

tlist = np.linspace(0, 100, 500)

width = 0.5

# resonant SQRT iSWAP gate
T0_1 = 20
T_gate_1 = (1*pi)/(4 * g1)

# resonant iSWAP gate
T0_2 = 60
T_gate_2 = (2*pi)/(4 * g2)

# %% [markdown]
# ### Operators, Hamiltonian and initial state

# %%
# cavity operators
a = tensor(destroy(N), qeye(2), qeye(2))
n = a.dag() * a

# operators for qubit 1
sm1 = tensor(qeye(N), destroy(2), qeye(2))
sz1 = tensor(qeye(N), sigmaz(), qeye(2))
n1 = sm1.dag() * sm1

# operators for qubit 2
sm2 = tensor(qeye(N), qeye(2), destroy(2))
sz2 = tensor(qeye(N), qeye(2), sigmaz())
n2 = sm2.dag() * sm2

# %%
# Hamiltonian using QuTiP
Hc = a.dag() * a
H1 = - 0.5 * sz1
H2 = - 0.5 * sz2
Hc1 = g1 * (a.dag() * sm1 + a * sm1.dag())
Hc2 = g2 * (a.dag() * sm2 + a * sm2.dag())

H = wc * Hc + w1 * H1 + w2 * H2 + Hc1 + Hc2

# %% [markdown]
# $\displaystyle H \quad =\quad \underbrace{\omega_c a^\dagger a}_\texttt{wc * Hc}\quad\underbrace{-\frac{1}{2}\omega_1 \sigma_{z}^{(1)}}_\texttt{w1 * H1}\quad \underbrace{-\frac{1}{2}\omega_2 \sigma_{z}^{(2)}}_\texttt{w2 * H2}
# \quad+ \underbrace{g_1 (a^\dagger \sigma_{-}^{(1)} + a \sigma_{+}^{(1)})}_\texttt{Hc1}
# \quad+ \underbrace{g_2 (a^\dagger \sigma_{-}^{(2)} + a \sigma_{+}^{(2)})}_\texttt{Hc2}$

# %%
H
# Out:
# Quantum object: dims = [[10, 2, 2], [10, 2, 2]], shape = [40, 40], type = oper, isherm = True
# Qobj data =
# [[ -15.70796327    0.            0.         ...,    0.            0.            0.        ]
#  [   0.           -3.14159265    0.         ...,    0.            0.            0.        ]
#  [   0.            0.            3.14159265 ...,    0.            0.            0.        ]
#  ...,
#  [   0.            0.            0.         ...,  279.60174617    0.            0.        ]
#  [   0.            0.            0.         ...,    0.          285.88493148
#      0.        ]
#  [   0.            0.            0.         ...,    0.            0.
#    298.45130209]]

# %%
# initial state: start with one of the qubits in its excited state
psi0 = tensor(basis(N,0),basis(2,1),basis(2,0))

# %% [markdown]
# $\displaystyle \underbrace{\left| \psi_0 \right\rangle}_\texttt{psi0} = \underbrace{\left| 0 \right\rangle}_\texttt{basis(N,0)}\otimes \underbrace{{\left| e \right\rangle}_1}_\texttt{basis(2,1)}\otimes\underbrace{{\left| g \right\rangle}_2}_\texttt{basis(2,0)} $

# %% [markdown]
# # Ideal two-qubit iSWAP gate

# %%
def step_t(w1, w2, t0, width, t):
    """
    Step function that goes from w1 to w2 at time t0
    as a function of t. 
    """
    return w1 + (w2 - w1) * (t > t0)


fig, axes = plt.subplots(1, 1, figsize=(8,2))
axes.plot(tlist, [step_t(0.5, 1.5, 50, 0.0, t) for t in tlist], 'k')
axes.set_ylim(0, 2)
fig.tight_layout()

# %% [markdown]
# $\displaystyle
# \omega_c (t) = \omega_c,\\
# \omega_1(t) =
# \begin{cases} \omega_1, &\mbox{if  } t<T_0^{(1)} \mbox{ or } t>T_0^{(1)}+T_{gate}^{(1)} \\
# \omega_c, &\mbox{if  } T_0^{(1)} < t < T_0^{(1)}+T_{gate}^{(1)} \end{cases},\\
# \omega_2(t) =\begin{cases} \omega_2, &\mbox{if  } t<T_0^{(2)} \mbox{ or } t>T_0^{(2)}+T_{gate}^{(2)} \\
# \omega_c, &\mbox{if  } T_0^{(2)} < t < T_0^{(2)}+T_{gate}^{(2)} \end{cases}.
# $

# %%
def wc_t(t, args=None):
    return wc

def w1_t(t, args=None):
    return w1 + step_t(0.0, wc-w1, T0_1, width, t) - step_t(0.0, wc-w1, T0_1+T_gate_1, width, t)

def w2_t(t, args=None):
    return w2 + step_t(0.0, wc-w2, T0_2, width, t) - step_t(0.0, wc-w2, T0_2+T_gate_2, width, t)


H_t = [[Hc, wc_t], [H1, w1_t], [H2, w2_t], Hc1+Hc2]

# %% [markdown]
# $\displaystyle H(t) \quad=\quad \underbrace{\omega_c (t) a^\dagger a}_\texttt{[Hc, wc_t]}\quad\underbrace{-\frac{1}{2} \omega_1 (t) \sigma_z^{(1)}}_\texttt{[H1, w1_t]}\quad \underbrace{- \frac{1}{2} \omega_2 (t) \sigma_z ^{(2)}}_\texttt{[H2, w2_t]} \quad+ \underbrace{g_1
#  (a^\dagger \sigma_{-}^{(1)} + a \sigma_{+}^{(1)}) + g_2 (a^\dagger \sigma_{-}^{(2)} + a \sigma_{+}^{(2)})}_\texttt{Hc1+Hc2}$

# %% [markdown]
# ### Evolve the system

# %%
res = mesolve(H_t, psi0, tlist, [], [])

# %% [markdown]
# ### Plot the results

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(12,8))

axes[0].plot(tlist, array(list(map(wc_t, tlist))) / (2*pi), 'r', linewidth=2, label="cavity")
axes[0].plot(tlist, array(list(map(w1_t, tlist))) / (2*pi), 'b', linewidth=2, label="qubit 1")
axes[0].plot(tlist, array(list(map(w2_t, tlist))) / (2*pi), 'g', linewidth=2, label="qubit 2")
axes[0].set_ylim(1, 6)
axes[0].set_ylabel("Energy (GHz)", fontsize=16)
axes[0].legend()

axes[1].plot(tlist, real(expect(n, res.states)), 'r', linewidth=2, label="cavity")
axes[1].plot(tlist, real(expect(n1, res.states)), 'b', linewidth=2, label="qubit 1")
axes[1].plot(tlist, real(expect(n2, res.states)), 'g', linewidth=2, label="qubit 2")
axes[1].set_ylim(0, 1)

axes[1].set_xlabel("Time (ns)", fontsize=16)
axes[1].set_ylabel("Occupation probability", fontsize=16)
axes[1].legend()

fig.tight_layout()

# %% [markdown]
# ### Inspect the final state

# %%
# extract the final state from the result of the simulation
rho_final = res.states[-1]
rho_final
# Out:
# Quantum object: dims = [[10, 2, 2], [1, 1, 1]], shape = [40, 1], type = ket
# Qobj data =
# [[ 0.00000000+0.j        ]
#  [ 0.70713514-0.00482569j]
#  [-0.70663362-0.02330592j]
#  [ 0.00000000+0.j        ]
#  [ 0.00789577-0.00013718j]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]
#  [ 0.00000000+0.j        ]]

# %%
# trace out the resonator mode and print the two-qubit density matrix
rho_qubits = ptrace(rho_final, [1,2])
rho_qubits
# Out:
# Quantum object: dims = [[2, 2], [2, 2]], shape = [4, 4], type = oper, isherm = True
# Qobj data =
# [[  6.23619654e-05+0.j           0.00000000e+00+0.j           0.00000000e+00+0.j
#     0.00000000e+00+0.j        ]
#  [  0.00000000e+00+0.j           5.00063399e-01+0.j
#    -4.99573000e-01+0.01989043j   0.00000000e+00+0.j        ]
#  [  0.00000000e+00+0.j          -4.99573000e-01-0.01989043j
#     4.99874239e-01+0.j           0.00000000e+00+0.j        ]
#  [  0.00000000e+00+0.j           0.00000000e+00+0.j           0.00000000e+00+0.j
#     0.00000000e+00+0.j        ]]

# %%
# compare to the ideal result of the sqrtiswap gate (plus phase correction) for the current initial state
rho_qubits_ideal = ket2dm(tensor(phasegate(0), phasegate(-pi/2)) * sqrtiswap() * tensor(basis(2,1), basis(2,0)))
rho_qubits_ideal
# Out:
# Quantum object: dims = [[2, 2], [2, 2]], shape = [4, 4], type = oper, isherm = True
# Qobj data =
# [[ 0.   0.   0.   0. ]
#  [ 0.   0.5  0.5  0. ]
#  [ 0.   0.5  0.5  0. ]
#  [ 0.   0.   0.   0. ]]

# %% [markdown]
# ### Fidelity and concurrence

# %%
fidelity(rho_qubits, rho_qubits_ideal)
# Out:
# 0.019895211840760076

# %%
concurrence(rho_qubits)
# Out:
# 0.99993761128281811

# %% [markdown]
# # Dissipative two-qubit iSWAP gate

# %% [markdown]
# ### Define collapse operators that describe dissipation

# %%
kappa = 0.0001
gamma1 = 0.005
gamma2 = 0.005

c_ops = [sqrt(kappa) * a, sqrt(gamma1) * sm1, sqrt(gamma2) * sm2]

# %% [markdown]
# $\displaystyle \textrm{collapse operators}(\texttt{c_ops})\ = \underbrace{\sqrt{\kappa} a}_\texttt{sqrt(kappa) * a} + \underbrace{\sqrt{\gamma_1} \sigma_-^{(1)}}_\texttt{sqrt(gamma1) * sm1} + \underbrace{\sqrt{\gamma_2} \sigma_-^{(2)}}_\texttt{sqrt(gamma2) * sm2}$

# %% [markdown]
# ### Evolve the system

# %%
res = mesolve(H_t, psi0, tlist, c_ops, [])

# %% [markdown]
# ### Plot the results

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(12,8))

axes[0].plot(tlist, array(list(map(wc_t, tlist))) / (2*pi), 'r', linewidth=2, label="cavity")
axes[0].plot(tlist, array(list(map(w1_t, tlist))) / (2*pi), 'b', linewidth=2, label="qubit 1")
axes[0].plot(tlist, array(list(map(w2_t, tlist))) / (2*pi), 'g', linewidth=2, label="qubit 2")
axes[0].set_ylim(1, 6)
axes[0].set_ylabel("Energy (GHz)", fontsize=16)
axes[0].legend()

axes[1].plot(tlist, real(expect(n, res.states)), 'r', linewidth=2, label="cavity")
axes[1].plot(tlist, real(expect(n1, res.states)), 'b', linewidth=2, label="qubit 1")
axes[1].plot(tlist, real(expect(n2, res.states)), 'g', linewidth=2, label="qubit 2")
axes[1].set_ylim(0, 1)

axes[1].set_xlabel("Time (ns)", fontsize=16)
axes[1].set_ylabel("Occupation probability", fontsize=16)
axes[1].legend()

fig.tight_layout()

# %% [markdown]
# ### Fidelity and concurrence

# %%
rho_final = res.states[-1]
rho_qubits = ptrace(rho_final, [1,2])

# %%
fidelity(rho_qubits, rho_qubits_ideal)
# Out:
# 1.3649306268570527e-09

# %%
concurrence(rho_qubits)
# Out:
# 0.67237860360918855

# %% [markdown]
# # Two-qubit iSWAP gate: Finite pulse rise time

# %%
def step_t(w1, w2, t0, width, t):
    """
    Step function that goes from w1 to w2 at time t0
    as a function of t, with finite rise time defined
    by the parameter width.
    """
    return w1 + (w2 - w1) / (1 + exp(-(t-t0)/width))


fig, axes = plt.subplots(1, 1, figsize=(8,2))
axes.plot(tlist, [step_t(0.5, 1.5, 50, width, t) for t in tlist], 'k')
axes.set_ylim(0, 2)
fig.tight_layout()

# %% [markdown]
# ### Evolve the system

# %%
res = mesolve(H_t, psi0, tlist, [], [])

# %% [markdown]
# ### Plot the results

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(12,8))

axes[0].plot(tlist, array(list(map(wc_t, tlist))) / (2*pi), 'r', linewidth=2, label="cavity")
axes[0].plot(tlist, array(list(map(w1_t, tlist))) / (2*pi), 'b', linewidth=2, label="qubit 1")
axes[0].plot(tlist, array(list(map(w2_t, tlist))) / (2*pi), 'g', linewidth=2, label="qubit 2")
axes[0].set_ylim(1, 6)
axes[0].set_ylabel("Energy (GHz)", fontsize=16)
axes[0].legend()

axes[1].plot(tlist, real(expect(n, res.states)), 'r', linewidth=2, label="cavity")
axes[1].plot(tlist, real(expect(n1, res.states)), 'b', linewidth=2, label="qubit 1")
axes[1].plot(tlist, real(expect(n2, res.states)), 'g', linewidth=2, label="qubit 2")
axes[1].set_ylim(0, 1)

axes[1].set_xlabel("Time (ns)", fontsize=16)
axes[1].set_ylabel("Occupation probability", fontsize=16)
axes[1].legend()

fig.tight_layout()

# %% [markdown]
# ### Fidelity and concurrence

# %%
rho_final = res.states[-1]
rho_qubits = ptrace(rho_final, [1,2])

# %%
fidelity(rho_qubits, rho_qubits_ideal)
# Out:
# 0.17500508085742658

# %%
concurrence(rho_qubits)
# Out:
# 0.92122640978788795

# %% [markdown]
# # Two-qubit iSWAP gate: Finite rise time with overshoot

# %%
from scipy.special import sici

def step_t(w1, w2, t0, width, t):
    """
    Step function that goes from w1 to w2 at time t0
    as a function of t, with finite rise time and 
    and overshoot defined by the parameter width.
    """

    return w1 + (w2-w1) * (0.5 + sici((t-t0)/width)[0]/(pi))


fig, axes = plt.subplots(1, 1, figsize=(8,2))
axes.plot(tlist, [step_t(0.5, 1.5, 50, width, t) for t in tlist], 'k')
axes.set_ylim(0, 2)
fig.tight_layout()

# %% [markdown]
# ### Evolve the system

# %%
res = mesolve(H_t, psi0, tlist, [], [])

# %% [markdown]
# ### Plot the results

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(12,8))

axes[0].plot(tlist, array(list(map(wc_t, tlist))) / (2*pi), 'r', linewidth=2, label="cavity")
axes[0].plot(tlist, array(list(map(w1_t, tlist))) / (2*pi), 'b', linewidth=2, label="qubit 1")
axes[0].plot(tlist, array(list(map(w2_t, tlist))) / (2*pi), 'g', linewidth=2, label="qubit 2")
axes[0].set_ylim(1, 6)
axes[0].set_ylabel("Energy (GHz)", fontsize=16)
axes[0].legend()

axes[1].plot(tlist, real(expect(n, res.states)), 'r', linewidth=2, label="cavity")
axes[1].plot(tlist, real(expect(n1, res.states)), 'b', linewidth=2, label="qubit 1")
axes[1].plot(tlist, real(expect(n2, res.states)), 'g', linewidth=2, label="qubit 2")
axes[1].set_ylim(0, 1)

axes[1].set_xlabel("Time (ns)", fontsize=16)
axes[1].set_ylabel("Occupation probability", fontsize=16)
axes[1].legend()

fig.tight_layout()

# %% [markdown]
# ### Fidelity and concurrence

# %%
rho_final = res.states[-1]
rho_qubits = ptrace(rho_final, [1,2])

# %%
fidelity(rho_qubits, rho_qubits_ideal)
# Out:
# 0.10568180682587267

# %%
concurrence(rho_qubits)
# Out:
# 0.9743883901797552

# %% [markdown]
# # Two-qubit iSWAP gate: Finite pulse rise time and dissipation

# %%
# increase the pulse rise time a bit
width = 0.6

# high-Q resonator but dissipative qubits
kappa  = 0.00001
gamma1 = 0.005
gamma2 = 0.005

c_ops = [sqrt(kappa) * a, sqrt(gamma1) * sm1, sqrt(gamma2) * sm2]

# %% [markdown]
# ### Evolve the system

# %%
res = mesolve(H_t, psi0, tlist, c_ops, [])

# %% [markdown]
# ### Plot results

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(12,8))

axes[0].plot(tlist, array(list(map(wc_t, tlist))) / (2*pi), 'r', linewidth=2, label="cavity")
axes[0].plot(tlist, array(list(map(w1_t, tlist))) / (2*pi), 'b', linewidth=2, label="qubit 1")
axes[0].plot(tlist, array(list(map(w2_t, tlist))) / (2*pi), 'g', linewidth=2, label="qubit 2")
axes[0].set_ylim(1, 6)
axes[0].set_ylabel("Energy (GHz)", fontsize=16)
axes[0].legend()

axes[1].plot(tlist, real(expect(n, res.states)), 'r', linewidth=2, label="cavity")
axes[1].plot(tlist, real(expect(n1, res.states)), 'b', linewidth=2, label="qubit 1")
axes[1].plot(tlist, real(expect(n2, res.states)), 'g', linewidth=2, label="qubit 2")
axes[1].set_ylim(0, 1)

axes[1].set_xlabel("Time (ns)", fontsize=16)
axes[1].set_ylabel("Occupation probability", fontsize=16)
axes[1].legend()

fig.tight_layout()

# %% [markdown]
# ### Fidelity and concurrence

# %%
rho_final = res.states[-1]
rho_qubits = ptrace(rho_final, [1,2])

# %%
fidelity(rho_qubits, rho_qubits_ideal)
# Out:
# 0.1187741818253028

# %%
concurrence(rho_qubits)
# Out:
# 0.62615691287530306

# %% [markdown]
# # Two-qubit iSWAP gate: Using tunable resonator and fixed-frequency qubits

# %%
# reduce the rise time
width = 0.25

def wc_t(t, args=None):
    return wc - step_t(0.0, wc-w1, T0_1, width, t) + step_t(0.0, wc-w1, T0_1+T_gate_1, width, t) \
              - step_t(0.0, wc-w2, T0_2, width, t) + step_t(0.0, wc-w2, T0_2+T_gate_2, width, t)

H_t = [[Hc, wc_t], H1 * w1 + H2 * w2 + Hc1 + Hc2]

# %% [markdown]
# $\displaystyle H(t) \quad=\quad \underbrace{\omega_c (t) a^\dagger a}_\texttt{[Hc, wc_t]}\quad\underbrace{-\frac{1}{2} \omega_1  \sigma_z^{(1)}}_\texttt{H1 * w1}\quad \underbrace{- \frac{1}{2} \omega_2 \sigma_z ^{(2)}}_\texttt{H2 * w2} \quad+ \underbrace{g_1
#  (a^\dagger \sigma_{-}^{(1)} + a \sigma_{+}^{(1)})}_\texttt{Hc1}\quad + \underbrace{g_2 (a^\dagger \sigma_{-}^{(2)} + a \sigma_{+}^{(2)})}_\texttt{Hc2}$

# %% [markdown]
# ### Evolve the system

# %%
res = mesolve(H_t, psi0, tlist, c_ops, [])

# %%
w1, w2
# Out:
# (18.84955592153876, 12.566370614359172)

# %% [markdown]
# ### Plot the results

# %%
fig, axes = plt.subplots(2, 1, sharex=True, figsize=(12,8))

axes[0].plot(tlist, array(list(map(wc_t, tlist))) / (2*pi), 'r', linewidth=2, label="cavity")
axes[0].plot(tlist, w1 * np.ones(len(tlist)) / (2*pi), 'b', linewidth=2, label="qubit 1")
axes[0].plot(tlist, w2 * np.ones(len(tlist)) / (2*pi), 'g', linewidth=2, label="qubit 2")
axes[0].set_ylim(1, 6)
axes[0].set_ylabel("Energy (GHz)", fontsize=16)
axes[0].legend()

axes[1].plot(tlist, real(expect(n, res.states)), 'r', linewidth=2, label="cavity")
axes[1].plot(tlist, real(expect(n1, res.states)), 'b', linewidth=2, label="qubit 1")
axes[1].plot(tlist, real(expect(n2, res.states)), 'g', linewidth=2, label="qubit 2")
axes[1].set_ylim(0, 1)

axes[1].set_xlabel("Time (ns)", fontsize=16)
axes[1].set_ylabel("Occupation probability", fontsize=16)
axes[1].legend()

fig.tight_layout()

# %% [markdown]
# ### Fidelity and concurrence

# %%
rho_final = res.states[-1]
rho_qubits = ptrace(rho_final, [1,2])

# %%
fidelity(rho_qubits, rho_qubits_ideal)
# Out:
# 0.020514992239428258

# %%
concurrence(rho_qubits)
# Out:
# 0.67366511968001552

# %% [markdown]
# ### Software versions

# %%
from qutip.ipynbtools import version_table

version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>matplotlib</td><td>1.4.0</td></tr><tr><td>Python</td><td>3.4.1 (default, Sep 20 2014, 19:44:17)
# [GCC 4.2.1 Compatible Apple LLVM 5.1 (clang-503.0.40)]</td></tr><tr><td>Numpy</td><td>1.9.0</td></tr><tr><td>Cython</td><td>0.21</td></tr><tr><td>QuTiP</td><td>3.0.1</td></tr><tr><td>SciPy</td><td>0.14.0</td></tr><tr><td>IPython</td><td>2.2.0</td></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td colspan='2'>Sat Sep 27 22:39:14 2014 JST</td></tr></table>
